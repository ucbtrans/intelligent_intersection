# %%
from __future__ import absolute_import
import sys
import os
sys.path.append(os.path.abspath('../source_code'))
import api

# %%
selection = api.get_data(file_name='../../../ComponentDr_NorthFirstSt_SJ.osm')

# %%
api.get_intersecting_streets(selection)
# Out:
# [(u'Charcot Avenue', u'Guadalupe - First Street'),
#  (u'Charcot Avenue', u'North 1st Street'),
#  (u'Component Drive', u'Guadalupe - First Street'),
#  (u'Component Drive', u'North 1st Street'),
#  (u'Component Drive', u'Zanker Road'),
#  (u'East Trimble Road', u'Guadalupe - First Street'),
#  (u'East Trimble Road', u'North 1st Street', u'West Trimble Road')]

# %%
x_data = api.get_intersection(('North 1st Street', 'Component Drive'), selection, crop_radius=100.0)
gws = api.get_guideways(x_data, 'all vehicle')
api.get_guideway_image(gws, x_data, alpha=0.8)
